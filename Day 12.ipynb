# %%
class moon:
    
    def __init__(self, x, y, z, name=''):
        self.revolutions = 0
        self.position = [x, y, z]
        self.velocity = [0, 0, 0]
        self.start_pos = self.position
        self.start_vel = self.position
        self.period = [[0],[0],[0]]
        self.period_diff = [[],[],[]]
        self.name = name
        
    def apply_velocity(self):
        self.revolutions += 1
        for i in range(3):
            self.position[i] += self.velocity[i]
            if self.repeat_axis(i):
                self.period[i].append(self.revolutions)
                if len(self.period[i]) >= 2:
                    self.period_diff[i].append(self.period[i][-1] - self.period[i][-2]) 
        
    def apply_gravity(self, other):
        for i, val in enumerate(other):
            vel = 0
            if self.position[i] < other[i]:
                vel = 1
            elif self.position[i] > other[i]:
                vel = -1
            self.velocity[i] += vel
    
    @property
    def kinetic_energy(self):
        x, y, z = self.velocity
        return abs(x) + abs(y) + abs(z)
    
    @property
    def potential_energy(self):
        x, y, z = self.position
        return abs(x) + abs(y) + abs(z)
    
    @property
    def total_energy(self):
        return self.potential_energy * self.kinetic_energy
    
    @property
    def state(self):
        return self.position + self.velocity
    
    def repeat_axis(self, axis):
        return self.position[axis] == self.start_pos[axis] and self.velocity[axis] == self.start_vel[axis]

# %%
#Example 1
io = moon(x=-1, y=0, z=2)
europa = moon(x=2, y=-10, z=-7)
ganymede = moon(x=4, y=-8, z=8)
callisto = moon(x=3, y=5, z=-1)

# %%
#Example 2
io = moon(x=-8, y=-10, z=0)
europa = moon(x=5, y=5, z=10)
ganymede = moon(x=2, y=-7, z=3)
callisto = moon(x=9, y=-8, z=-3)

# %%
# Real input
io = moon(x=-1, y=7, z=3, name='io')
europa = moon(x=12, y=2, z=-13, name='europa')
ganymede = moon(x=14, y=18, z=-8, name='ganymede')
callisto = moon(x=17, y=4, z=-4, name='callisto')

# %%
moons = [io, europa, ganymede, callisto]
moon_names = ['io','europa', 'ganymede', 'callisto']
pairs = [
    (io, europa),
    (io, ganymede),
    (io, callisto),
    (europa, ganymede),
    (europa, callisto),
    (ganymede, callisto)
]
steps = 1000000

# %%
for step in range(steps):
    for pair in pairs:
        pair[0].apply_gravity(pair[1].position)
        pair[1].apply_gravity(pair[0].position)
    for m in moons:
        m.apply_velocity()

# %% [markdown]
# ### Part 1

# %% [markdown]
# Printout for comparison

# %%
for m in moons:
    pos_x, pos_y, pos_z = m.position
    vel_x, vel_y, vel_z = m.velocity
    print(F'pos=(x={pos_x}, y={pos_y}, z={pos_z}), vel=(x={vel_x}, y={vel_y}, z={vel_z})')

# %% [markdown]
# Get total energy

# %%
pot = 0
kin = 0
tot = 0
for m in moons:
    pot += m.potential_energy
    kin += m.kinetic_energy
    tot += m.total_energy

# %% [markdown]
# ### Part 2

# %%
def get_period_list(possible):
    seq = possible[1:]
    max_len = len(seq)//2
    for x in range(2, max_len):
        if seq[0:x] == seq[x:2*x]:
            return seq[0:x]
    return []

# %%
p = []
for m in moons:
    print(m.name)
    for axis in range(3):
        print(F'  Axis {axis}')
        period = get_period_list(m.period_diff[axis])
        print ('  ', period)
        period_len = 0
        for l in period:
            period_len += l
        if period_len not in p:
            p.append(period_len)
        print('  ', period_len)
# Out:
# io
#   Axis 0
 172, 908, 2013, 1, 155, 25, 27, 1429, 1023, 5, 763, 904, 126, 1852, 175, 5, 7, 999, 33, 665, 987, 103, 862, 474, 676, 465, 1003, 436, 376, 1248, 4903, 1974, 1855, 4969, 5, 1277, 1089, 582, 5, 563, 988, 2101, 988, 563, 5, 582, 1089, 1277, 5, 4969, 1855, 1974, 4903, 1248, 376, 436, 1003, 465, 676, 474, 862, 103, 987, 665, 33, 999, 7, 5, 175, 1852, 126, 904, 763, 5, 1023, 1429, 27, 25, 155, 1, 2013, 908, 172, 32, 2845, 492, 11, 2580, 753, 68, 96, 581, 80, 197, 1921, 55, 116, 528, 399, 660, 145, 1145, 72, 379, 142, 545, 19, 85, 63, 82, 260, 245, 124, 481, 51, 338, 215, 36, 591, 21, 547, 417, 68, 803, 159, 20, 393, 43, 191, 45, 331, 21, 154, 17, 161, 167, 112, 844, 3, 722, 207, 568, 481, 294, 51, 266, 1912, 19, 25, 167, 127, 141, 120, 40, 160, 60, 33, 380, 5, 260, 107, 527, 1, 180, 74, 112, 6, 3, 277, 1, 119, 58, 593, 1499, 64, 27, 1, 317, 225, 23, 376, 68, 617, 444, 21, 558, 32, 51, 17, 594, 413, 63, 142, 10, 34, 72, 9, 11, 9, 11, 9, 143, 7, 44, 23, 78, 32, 5, 16, 49]
#    144624

# %%
p
# Out:
# [231614, 48118, 144624, 96236]

# %% [markdown]
# ## This approach would take way too long
# Get the state of everything - list of all positions and velocities in moon order

# %%
def state_of_universe(moons):
    state = []
    for m in moons:
        state += m.state
    return state

# %% [markdown]
# Calculate total steps to get back to a previous state

# %%
repeat_steps = 0
steps
cur_state = state_of_universe(moons)
while cur_state not in prev_states:
    for pair in pairs:
        pair[0].apply_gravity(pair[1].position)
        pair[1].apply_gravity(pair[0].position)
    for m in moons:
        m.apply_velocity()
    prev_states.append(cur_state)
    cur_state = state_of_universe(moons)
    steps += 1

# %%
for step in steps:
        for pair in pairs:
        pair[0].apply_gravity(pair[1].position)
        pair[1].apply_gravity(pair[0].position)
    for m in moons:
        m.apply_velocity()
        for axis in ['x','y','z']:
            if m.repeat_axis()
# Out:
# 2772

# %%
io.position
# Out:
# [2, 2, 4]

# %%
for m in moons:
    print(F'{m.name} - x: {len(m.period[0])}, y: {len(m.period[1])}, z: {len(m.period[2])})')
# Out:
# io - x: 27, y: 105, z: 62)
# europa - x: 55, y: 69, z: 58)
# ganymede - x: 48, y: 94, z: 76)
# callisto - x: 43, y: 83, z: 64)

# %%
for m in moons:
    print(F'{m.name} - x: {len(m.period_diff[0])}, y: {len(m.period_diff[1])}, z: {len(m.period_diff[2])})')
# Out:
# io - x: 26, y: 104, z: 61)
# europa - x: 54, y: 68, z: 57)
# ganymede - x: 47, y: 93, z: 75)
# callisto - x: 42, y: 82, z: 63)

# %%
3+15+3+7
# Out:
# 28

# %%
4+4+6+3+6+4+4+13
# Out:
# 44

# %%
ganymede.period_diff[2][:20]
# Out:
# [18, 9, 35, 9, 35, 9, 35, 9, 35, 9, 35, 9, 35, 9, 35, 9, 35, 9, 35, 9]

# %%
callisto.period_diff[2][:20]

# %%
p
# Out:
# [231614, 48118, 144624, 96236]
